# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cufflinks as cf
from IPython.display import display,HTML

# %%
#Leo mi archivo.csv
Covid = pd.read_csv("COVID19MEXICO_Bueno.csv")
#Filtro por filas
Covid= Covid.iloc[0:100000,: ]
Covid
# Out:
# C:\Users\papit\AppData\Local\Temp\ipykernel_4136\2809429721.py:2: DtypeWarning:
#
# Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2     NaN         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         NaN
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
#        SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  ...  OTRO_CASO  \
# 0       2.0           27           23            8.0  ...        2.0
# 1       2.0           25           25            1.0  ...        2.0
# 2       1.0            9            9           14.0  ...        2.0
# 3       1.0            9            9            2.0  ...        1.0
# 4       1.0            9            9            7.0  ...        1.0
# ...     ...          ...          ...            ...  ...        ...
# 99995   1.0           11           15           31.0  ...        2.0
# 99996   2.0           15           15           95.0  ...        1.0
# 99997   2.0           28           28           22.0  ...        1.0
# 99998   1.0           15            9            6.0  ...        1.0
# 99999   1.0            9            9            7.0  ...        2.0
#
#       TOMA_MUESTRA_LAB RESULTADO_LAB TOMA_MUESTRA_ANTIGENO  \
# 0                    2            97                     1
# 1                    2            97                     1
# 2                    1             1                     2
# 3                    2            97                     1
# 4                    2            97                     1
# ...                ...           ...                   ...
# 99995                1             2                     1
# 99996                2            97                     1
# 99997                2            97                     1
# 99998                2            97                     1
# 99999                2            97                     1
#
#        RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  \
# 0                     2.0                    7        99             México
# 1                     2.0                    7        99             México
# 2                    97.0                    3        99             México
# 3                     2.0                    7        99             México
# 4                     2.0                    7        99             México
# ...                   ...                  ...       ...                ...
# 99995                 2.0                    7        99             México
# 99996                 2.0                    7        99             México
# 99997                 1.0                    3        99             México
# 99998                 1.0                    3        99             México
# 99999                 1.0                    3        99             México
#
#        PAIS_ORIGEN  UCI
# 0               97   97
# 1               97   97
# 2               97   97
# 3               97   97
# 4               97   97
# ...            ...  ...
# 99995           97   97
# 99996           97   97
# 99997           97   97
# 99998           97   97
# 99999           97   97
#
# [100000 rows x 41 columns]

# %% [markdown]
# # Identificación de valores nulos

# %%
#Se comprueban valores nulos 
valores_nulos=Covid.isnull().sum()
valores_nulos=Covid.isnull().sum()
valores_nulos
#No se encuentran valores nulos
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   1
# ENTIDAD_UM               1
# SEXO                     1
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            1
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     3
# NACIONALIDAD             0
# EMBARAZO                 2
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             1
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               1
# OTRO_CASO                1
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# TOMA_MUESTRA_ANTIGENO    0
# RESULTADO_ANTIGENO       1
# CLASIFICACION_FINAL      0
# MIGRANTE                 0
# PAIS_NACIONALIDAD        2
# PAIS_ORIGEN              0
# UCI                      0
# dtype: int64

# %%
#Comenzamos con los nulos encontrados en SECTOR, ENTIDAD_UM, SEXO
Covid["SECTOR"]= Covid["SECTOR"].fillna(Covid["SECTOR"].mode) 
Covid["ENTIDAD_UM"]= Covid["ENTIDAD_UM"].fillna(Covid["ENTIDAD_UM"].mode)
Covid["SEXO"]= Covid["SEXO"].dropna(0) 
Covid["MUNICIPIO_RES"]= Covid["MUNICIPIO_RES"].fillna(Covid["MUNICIPIO_RES"].mode) 
Covid["EDAD"]= Covid["EDAD"].fillna(Covid["EDAD"].mean) 
Covid["EMBARAZO"]= Covid["EMBARAZO"].dropna(0) 
Covid["PAIS_NACIONALIDAD"]= Covid["PAIS_NACIONALIDAD"].fillna("México") 
Covid["HIPERTENSION"]= Covid["HIPERTENSION"].fillna(Covid["HIPERTENSION"].mode)

# %%
#Hacemos la comprobación de NAs
#Se comprueban valores nulos 
valores_nulos=Covid.isnull().sum().sum()
valores_nulos
# Out:
# 0

# %%
#Reemplazamos los 4 valores restantes en el dataframe 
Covid =Covid.fillna(0) 
Covid
#Comprobamos nuevamente 
valores_nulos=Covid.isnull().sum().sum()
valores_nulos
# Out:
# 0

# %% [markdown]
# # Identificación de outliers

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe para identificar outliers
fig = plt.figure(figsize =(15, 8))
data2.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\papit\Desktop\Carpeta\Actividad_4\Actividad-4\9_covid.ipynb Celda 9 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/papit/Desktop/Carpeta/Actividad_4/Actividad-4/9_covid.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> #Realizamos diagrama de caja o bigote de cada columna del dataframe para identificar outliers
#       <a href='vscode-notebook-cell:/c%3A/Users/papit/Desktop/Carpeta/Actividad_4/Actividad-4/9_covid.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> fig = plt.figure(figsize =(15, 8))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/papit/Desktop/Carpeta/Actividad_4/Actividad-4/9_covid.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> data2.plot(kind='box', vert=False)
#       <a href='vscode-notebook-cell:/c%3A/Users/papit/Desktop/Carpeta/Actividad_4/Actividad-4/9_covid.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> plt.title("Valores Atípicos del Dataframe")
#       <a href='vscode-notebook-cell:/c%3A/Users/papit/Desktop/Carpeta/Actividad_4/Actividad-4/9_covid.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> plt.show()
#
# NameError: name 'data2' is not defined
